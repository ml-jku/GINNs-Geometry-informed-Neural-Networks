# %%
import os, sys

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pts = np.load('examples/cantilever/output/mu-9.186761616039e-11-hmin-5.695e-02-params-[0.5, 3.0, 0.0, -1.0, 75.38461538461539, 64.61538461538461, 0.1]-solver-BensonMunson/0_coords.npy')
rho = np.load('examples/cantilever/output/mu-9.186761616039e-11-hmin-5.695e-02-params-[0.5, 3.0, 0.0, -1.0, 75.38461538461539, 64.61538461538461, 0.1]-solver-BensonMunson/0_rho.npy')

# %%
pts.shape
# Out:
# (988, 2)

# %%
rho.shape
# Out:
# (988,)

# %%
plt.scatter(pts[:,0], pts[:,1], c=rho)
